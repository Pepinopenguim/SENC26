# %% [markdown]
# ### Objetivos
#
# > Precisamos criar um notebook que trate e analise os dados no formato disponibilizado pela hidroweb.
# > A demanda entregue foi a seguinte:
# - Como é o fluxo de água no rio historicamente? E quais são os máximos **anuais**?
# - Como relacionar a cota do rio com a vazão?

# %% [markdown]
# ## Importação de arquivos e tratamento inicial

# %%
import pandas as pd

vazoes = pd.read_csv(r"data/46543000_Vazoes.csv", sep=";", skiprows=15, encoding="utf-8")
vazoes.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 585 entries, 0 to 584
# Data columns (total 78 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EstacaoCodigo         585 non-null    int64
#  1   NivelConsistencia     585 non-null    int64
#  2   Data                  585 non-null    str
#  3   Hora                  0 non-null      float64
#  4   MediaDiaria           585 non-null    int64
#  5   MetodoObtencaoVazoes  585 non-null    int64
#  6   Maxima                584 non-null    str
#  7   Minima                584 non-null    str
#  8   Media                 584 non-null    str
#  9   DiaMaxima             584 non-null    float64
#  10  DiaMinima             584 non-null    float64
#  11  MaximaStatus          571 non-null    float64
#  12  MinimaStatus          576 non-null    float64
#  13  MediaStatus           585 non-null    int64
#  14  MediaAnual            48 non-null     str
# ...
